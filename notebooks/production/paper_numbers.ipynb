# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams.update({"font.size": 14})
plt.rcParams.update({"axes.axisbelow": True})

# %% [markdown]
# # Raw data

# %%
raw_df = pd.read_parquet("../../data/raw_data/search-arena-chat-24k.parquet")

# %%
len(raw_df)
# Out:
# 24069

# %%
domain_enriched_df = pd.read_parquet(
    "../../data/intermediate/cleaned_arena_data/domains_enriched.parquet"
)
citations_enriched_df = pd.read_parquet(
    "../../data/intermediate/cleaned_arena_data/citations_enriched.parquet"
)

# %%
domain_enriched_df
# Out:
#                  domain  citation_count  political_leaning_score  \
# 0           youtube.com           19749                -0.022156
# 1         wikipedia.org           14922                -0.246107
# 2            reddit.com            9476                -0.193405
# 3            github.com            3701                -0.351924
# 4            google.com            3252                -0.131220
# ...                 ...             ...                      ...
# 83528  mestnoepravo.com               1                      NaN
# 83529      geodatos.net               1                      NaN
# 83530         thelib.ru               1                      NaN
# 83531           6lib.ru               1                      NaN
# 83532     shinjokun.com               1                      NaN
#
#       political_leaning  domain_quality_score   domain_quality  \
# 0        center_leaning              0.375093      low_quality
# ...

# %%
citations_enriched_df
# Out:
#           citation_id    response_id  citation_number  \
# 0       cite_00000000  resp_00000000                1
# 1       cite_00000001  resp_00000000                2
# 2       cite_00000002  resp_00000000                3
# 3       cite_00000003  resp_00000000                4
# 4       cite_00000004  resp_00000000                5
# ...               ...            ...              ...
# 366082  cite_00366082  resp_00065766                3
# 366083  cite_00366083  resp_00065766                4
# 366084  cite_00366084  resp_00065766                5
# 366085  cite_00366085  resp_00065766                6
# 366086  cite_00366086  resp_00065766                7
#
#                                                       url  \
# 0              https://www.pixpa.com/blog/types-of-models
# 1       https://brainfall.com/quizzes/which-supermodel...
# 2       https://uquiz.com/quiz/CsHn01/which-supermodel...
# 3       https://www.quotev.com/quizzes/Which+Model+Are...
# ...

# %%
news_citations = pd.read_parquet(
    "../../data/intermediate/citation_analysis/news_citations.parquet"
)

# %%
news_citations.columns
# Out:
# Index(['citation_id', 'response_id', 'citation_number', 'url', 'domain_full',
#        'domain', 'url_valid', 'citation_order', 'political_leaning_score',
#        'political_leaning', 'domain_quality_score', 'domain_quality',
#        'domain_classification', 'question_id', 'thread_id', 'turn_number',
#        'model_name_llm', 'model_name_raw', 'model_side', 'citation_format',
#        'winner', 'primary_intent', 'secondary_intent', 'total_turns',
#        'timestamp', 'model_won', 'model_lost', 'model_tied', 'model_family'],
#       dtype='object')

# %%
news_citations
# Out:
#          citation_id    response_id  citation_number  \
# 0      cite_00000001  resp_00000000                2
# 1      cite_00000006  resp_00000001                2
# 2      cite_00000015  resp_00000003                5
# 3      cite_00000016  resp_00000003                6
# 4      cite_00000033  resp_00000005                6
# ...              ...            ...              ...
# 32860  cite_00365852  resp_00065722                6
# 32861  cite_00365887  resp_00065728                5
# 32862  cite_00365909  resp_00065730                5
# 32863  cite_00365916  resp_00065730               12
# 32864  cite_00365944  resp_00065736                3
#
#                                                      url  \
# 0      https://brainfall.com/quizzes/which-supermodel...
# 1      https://brainfall.com/quizzes/which-supermodel...
# 2      https://my.clevelandclinic.org/health/diseases...
# 3      https://kidshealth.org/en/parents/diamond-blac...
# ...
